# %% [markdown]
# Ejercicio 1

# %%
velocidadA=49
if velocidadA>25:
    print("El asteroide se acerca a la tierra demasiado rápido.")
else:
    print("No hay peligro.")
# Out:
# El asteroide se acerca a la tierra demasiado rápido.

# %% [markdown]
# Ejercicio 2

# %%
velodidadA=19
if velocidadA>=20:
    print("Hay posibilidad de que se produsca un rayo.")
else:
    print("No hay posibilidad de que se produsca un rayo.")
# Out:
# Hay posibilidad de que se produsca un rayo.

# %% [markdown]
# Ejercicio 3

# %%
velocidadA=25
tamañoA=40
if velocidadA >25 and tamañoA>25:
    print("Advertencia un asteroide llegara pronto a la tierra.")
elif velocidadA>=20:
    print("Se produce un rayo.")
elif tamañoA<25:
    print("No se produce nada.")
else:
    print("No pasa nada.")
# Out:
# Se produce un rayo.
