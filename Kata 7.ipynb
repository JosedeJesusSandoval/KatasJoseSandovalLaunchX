# %% [markdown]
# Ejercicio 1

# %%
planets=[]
new_planet=''

while new_planet.lower() != 'done':
    if new_planet:
        planets.append(new_planet)
    new_planet=input('Dime el nombre de un planeta sino escribe done: ')

# %% [markdown]
# Ejercicio 2

# %%
planets=[]
new_planet=''

while new_planet.lower() != 'done':
    if new_planet:
        planets.append(new_planet)
    new_planet=input('Dime el nombre de un planeta sino escribe done: ')

for planet in planets:
    print(planet)
# Out:
# Venus
# Marte
# Tierra
